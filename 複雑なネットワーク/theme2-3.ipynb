# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

G = nx.watts_strogatz_graph(n = 10, k = 4, p = 0.5)#スモールワールド
pos = nx.circular_layout(G)
print('L=', nx.average_shortest_path_length(G))
print('C=', nx.average_clustering(G))
plt.figure(figsize = (6, 6))
nx.draw_networkx(G, pos)
# Out:
# L= 1.6444444444444444
# C= 0.42666666666666664

# %%
G = nx.watts_strogatz_graph(n = 10, k = 4, p = 1)

pos = nx.circular_layout(G)
print('L=', nx.average_shortest_path_length(G))
print('C=', nx.average_clustering(G))
plt.figure(figsize = (6, 6))
nx.draw_networkx(G, pos)
# Out:
# L= 1.6222222222222222
# C= 0.4133333333333333

# %%
G = nx.watts_strogatz_graph(n = 10, k = 4, p = 0)

print('L=', nx.average_shortest_path_length(G))
print('C=', nx.average_clustering(G))
plt.figure(figsize = (6, 6))
nx.draw_networkx(G, pos)
# Out:
# L= 1.6666666666666667
# C= 0.5

# %%
G = nx.random_regular_graph(4, 10)#レギュラーネットワークの作成
plt.figure(figsize = (6, 6))
nx.draw_networkx(G, pos)

# %%
G=nx.erdos_renyi_graph(10, 0.5) # ERネットワークの作成
plt.figure(figsize = (6, 6))
pos = nx.circular_layout(G)
nx.draw_networkx(G, pos)

# %%
p = np.arange(0,1,0.001)
L = []
i = 0
for i in range(len(p)):
    G = nx.watts_strogatz_graph(500,4,p[i])
    L_1 = nx.average_shortest_path_length(G)
    L.append(L_1)
plt.plot(p,L)

# %%
p = np.arange(0,1,0.001)
C = []
i = 0
for i in range(len(p)):
    G = nx.watts_strogatz_graph(500,4,p[i])
    C_1 = nx.average_clustering(G)
    C.append(C_1)
plt.plot(p,C)

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
G = nx.watts_strogatz_graph(n = 500, k = 4, p = 1)
print('L=', nx.average_shortest_path_length(G))
print('C=', nx.average_clustering(G))
# Out:
# L= 4.755695390781563
# C= 0.005117460317460318

# %%
G = nx.watts_strogatz_graph(n = 500, k = 4, p = 0)
print('L=', nx.average_shortest_path_length(G))
print('C=', nx.average_clustering(G))
# Out:
# L= 62.875751503006015
# C= 0.5

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import EoN # EoNのインポート

# %%
RG = nx.random_graphs.random_regular_graph(4, 100)

# %%
t1, S1, I1, R1 = EoN.fast_SIR(RG, 0.5, 0.1)

# 個体数変化のグラフ
plt.plot(t1, S1, label='S')
plt.plot(t1, I1, label='I')
plt.plot(t1, R1, label='R')
plt.xlabel('t')
plt.legend()

# %%
t2, S2, I2, R2 = EoN.fast_SIR(RG, 0.5, 0.5)

# 個体数変化のグラフ
plt.plot(t2, S2, label='S')
plt.plot(t2, I2, label='I')
plt.plot(t2, R2, label='R')
plt.xlabel('t')
plt.legend()

# %%
t3, S3, I3, R3 = EoN.fast_SIR(RG, 0.5, 1.0)

# 個体数変化のグラフ
plt.plot(t3, S3, label='S')
plt.plot(t3, I3, label='I')
plt.plot(t3, R3, label='R')
plt.xlabel('t')
plt.legend()

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import EoN # EoNのインポート

# %%
WS = nx.watts_strogatz_graph(100, 4, 0.5)

# %%
t1, S1, I1, R1 = EoN.fast_SIR(WS, 0.5, 0.1)

# 個体数変化のグラフ
plt.plot(t1, S1, label='S')
plt.plot(t1, I1, label='I')
plt.plot(t1, R1, label='R')
plt.xlabel('t')
plt.legend()

# %%
t2, S2, I2, R2 = EoN.fast_SIR(WS, 0.5, 0.5)

# 個体数変化のグラフ
plt.plot(t2, S2, label='S')
plt.plot(t2, I2, label='I')
plt.plot(t2, R2, label='R')
plt.xlabel('t')
plt.legend()

# %%
t3, S3, I3, R3 = EoN.fast_SIR(WS, 0.5, 1.0)

# 個体数変化のグラフ
plt.plot(t3, S3, label='S')
plt.plot(t3, I3, label='I')
plt.plot(t3, R3, label='R')
plt.xlabel('t')
plt.legend()

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import EoN # EoNのインポート

# %%
ER = nx.random_graphs.erdos_renyi_graph(100, 0.5)

# %%
t, S, I, R = EoN.fast_SIR(ER, 0.5, 0.1)

# 個体数変化のグラフ
plt.plot(t, S, label='S')
plt.plot(t, I, label='I')
plt.plot(t, R, label='R')
plt.xlabel('t')
plt.legend()

# %%
t, S, I, R = EoN.fast_SIR(ER, 0.5, 0.5)

# 個体数変化のグラフ
plt.plot(t, S, label='S')
plt.plot(t, I, label='I')
plt.plot(t, R, label='R')
plt.xlabel('t')
plt.legend()

# %%
t, S, I, R = EoN.fast_SIR(ER, 0.5, 1.0)

# 個体数変化のグラフ
plt.plot(t, S, label='S')
plt.plot(t, I, label='I')
plt.plot(t, R, label='R')
plt.xlabel('t')
plt.legend()
